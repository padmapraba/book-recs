# %%
import pandas as pd

# %%
df = pd.read_csv('top2k_book_descriptions.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'book_id', 'best_book_id', 'work_id', 'books_count',
#        'isbn', 'isbn13', 'authors', 'original_publication_year',
#        'original_title', 'title', 'language_code', 'average_rating',
#        'ratings_count', 'work_ratings_count', 'work_text_reviews_count',
#        'ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5',
#        'image_url', 'small_image_url', 'goodreads_book_id', 'tag_name',
#        'description'],
#       dtype='object')

# %%
df.language_code.value_counts()
# Out:
# language_code
# eng      1390
# en-US     455
# en-GB      46
# en-CA      16
# spa         4
# fre         4
# nl          1
# ara         1
# ger         1
# Name: count, dtype: int64

# %%
df = df[(df['language_code'] == 'eng') | (df['language_code'] == 'en-US')]

# %%
data  = df[['original_title','description','authors','image_url']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1845 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  1808 non-null   object
#  1   description     1834 non-null   object
#  2   authors         1845 non-null   object
# dtypes: object(3)
# memory usage: 57.7+ KB

# %%
data = data.dropna(subset=['description']).reset_index()

# %%
data.iloc[0].image_url
# Out:
# 'https://images.gr-assets.com/books/1447303603m/2767052.jpg'

# %% [markdown]
# ## pre-process descriptions
# - lowercasing
# - remove punctuation
# - remove special characters
# - handle contractions
# - remove stop words

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def preprocess_text(text):
    # Lowercasing
    text = text.lower()
    # Removing punctuation
    text = text.translate(str.maketrans(' ', ' ', string.punctuation))
    # Tokenization
    tokens = word_tokenize(text)
    # Removing stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    tokens = [token for token in tokens if token != 'isbn']
    tokens = [token for token in tokens if token != 'isbn13']
    tokens = [token for token in tokens if token != 'isbn10']
    # Remove numerical digits
    tokens = [token for token in tokens if not token.isdigit()]
    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return ' '.join(tokens)


# Preprocess the description
data['processed_text'] = data['description'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/padmaprabagaran/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/padmaprabagaran/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/padmaprabagaran/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
data
# Out:
#       index                            original_title  \
# 0         0                          The Hunger Games
# 1         1  Harry Potter and the Philosopher's Stone
# 2         2                                  Twilight
# 3         3                     To Kill a Mockingbird
# 4         4                          The Great Gatsby
# ...     ...                                       ...
# 1829   1995         Simon vs. the Homo Sapiens Agenda
# 1830   1996                                Perfection
# 1831   1997                         Come Away with Me
# 1832   1998             Ms. Marvel, Vol. 1: No Normal
# 1833   1999                 A Court of Wings and Ruin
#
#                                             description  \
# 0     WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1     Harry Potter's life is miserable. His parents ...
# 2     About three things I was absolutely positive.F...
# 3     The unforgettable novel of a childhood in a sl...
# 4     Alternate Cover Edition ISBN: 0743273567 (ISBN...
# ...                                                 ...
# 1829  Sixteen-year-old and not-so-openly gay Simon S...
# 1830  Zoe is used to taking care of herself and has ...
# 1831  An alternate cover edition can be found here.B...
# 1832  Marvel Comics presents the new Ms. Marvel, the...
# 1833  Looming war threatens all Feyre holds dear in ...
#
#                                authors  \
# 0                      Suzanne Collins
# 1          J.K. Rowling, Mary GrandPré
# 2                      Stephenie Meyer
# 3                           Harper Lee
# 4                  F. Scott Fitzgerald
# ...                                ...
# 1829                  Becky Albertalli
# 1830                    R.L. Mathewson
# 1831                     Kristen Proby
# 1832  G. Willow Wilson, Adrian Alphona
# 1833                     Sarah J. Maas
#
#                                          processed_text
# 0     winning mean fame fortunelosing mean certain d...
# 1     harry potter life miserable parent dead he stu...
# 2     three thing absolutely positivefirst edward va...
# 3     unforgettable novel childhood sleepy southern ...
# 4     alternate cover edition 9780743273565the great...
# ...                                                 ...
# 1829  sixteenyearold notsoopenly gay simon spier pre...
# 1830  zoe used taking care long ago accepted anythin...
# 1831  alternate cover edition found herebeing confro...
# 1832  marvel comic present new m marvel groundbreaki...
# 1833  looming war threatens feyre hold dear third vo...
#
# [1834 rows x 5 columns]

# %% [markdown]
# ## Calculate similarity of books based on its description

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

doc1 = data.iloc[1833]
doc2 = data.iloc[4]
# corpus = [doc1.description,doc2.description]
corpus = [doc1.processed_text,doc2.processed_text]

vectorizer = TfidfVectorizer()

trsfm=vectorizer.fit_transform(corpus)
# print(trsfm.toarray())
pd.DataFrame(trsfm.toarray(),columns=vectorizer.get_feature_names_out(),index=['Document 1','Document 2'])
# Out:
#             1920sthe  9780743273565the  acclaimed  achievement       age  \
# Document 1  0.000000          0.000000   0.000000     0.000000  0.000000
# Document 2  0.116981          0.116981   0.116981     0.116981  0.116981
#
#                 ally  alternate   america   amongst      army  ...     trust  \
# Document 1  0.103345   0.000000  0.000000  0.103345  0.103345  ...  0.103345
# Document 2  0.000000   0.116981  0.116981  0.000000  0.000000  ...  0.000000
#
#             twentiethcentury  unexpected      upon    volume      war  \
# Document 1          0.000000    0.103345  0.103345  0.103345  0.20669
# Document 2          0.116981    0.000000  0.000000  0.000000  0.00000
#
#              wealthy    wellas     world      york
# Document 1  0.000000  0.103345  0.103345  0.147062
# Document 2  0.116981  0.000000  0.000000  0.083233
#
# [2 rows x 114 columns]

# %%
cosine_similarity(trsfm[0:1], trsfm)
# Out:
# array([[1.        , 0.03596528]])

# %%
cosine_similarity(trsfm[0:1], trsfm)
# Out:
# array([[1.        , 0.09180299]])

# %% [markdown]
# ## create a similarity matrix with the data

# %%
vectorizer = TfidfVectorizer()

# Fit and transform the corpus (processed_text column)
tfidf_matrix = vectorizer.fit_transform(data['processed_text'])

# Convert the TF-IDF matrix to DataFrame
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out(), index=data.index)

# %%
# Compute the cosine similarity matrix
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Function to get recommendations based on cosine similarity
def get_recommendations(book_index, cosine_sim=cosine_sim, df=df, top_n=5):
    # Get the index of the book
    idx = book_index if isinstance(book_index, int) else df[df['original_title'] == book_index].index[0]
    
    # Get pairwise similarity scores with other books
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Sort books based on similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the top N similar books (excluding itself)
    sim_scores = sim_scores[1:top_n+1]
    
    # Get book indices
    book_indices = [i[0] for i in sim_scores]
    
    # Return recommended books
    return df.iloc[book_indices]

# Example: Get recommendations for a book by index or title
book_index_or_title = 'The Hunger Games'  # Change this to the book index or title you want recommendations for
recommendations = get_recommendations(book_index_or_title)
print(recommendations[['original_title', 'authors']])
# Out:
#            original_title          authors
# 19             Mockingjay  Suzanne Collins
# 16          Catching Fire  Suzanne Collins
# 1339  Horton Hears a Who!        Dr. Seuss
# 505               The One       Kiera Cass
# 715            The Choice  Nicholas Sparks

# %%
data['original_title'].sample(20)
# Out:
# 766                                            Seabiscuit
# 118                                   The Handmaid's Tale
# 1348                                             One Shot
# 976                                       Shadow of Night
# 732                                Snow Falling on Cedars
# 1381    Sex, Drugs, and Cocoa Puffs: A Low Culture Man...
# 60                                  The Girl on the Train
# 935                                   Wolves of the Calla
# 1921                                         Bloody Bones
# 633                                  I've Got Your Number
# 1048                                     Handle with Care
# 1259                                         To the Nines
# 159                                    Great Expectations
# 469     I Am Malala: The Girl Who Stood Up for Educati...
# 1122                                        Summer Knight
# 377                                          The Namesake
# 1802                                             Faefever
# 1498                                           The Twelve
# 564                                                   NaN
# 1861                                            Hogfather
# Name: original_title, dtype: object

# %%
recommendations = get_recommendations('The Bourne Supremacy')
print(recommendations[['original_title', 'authors']])
# Out:
#                 original_title                      authors
# 1106                  Mr Maybe                   Jane Green
# 416        The Thirteenth Tale            Diane Setterfield
# 881               Storm Island                  Ken Follett
# 1745  A Bear Called Paddington  Michael Bond, Peggy Fortnum
# 968                 Steelheart            Brandon Sanderson

# %%
df = pd.read_csv('data/scraped_data.csv')
print(len(df))
df2 = pd.read_csv('data/scraped_data2.csv')
print(len(df2))
# Out:
# 9900
# 4900

# %%
df3 = pd.concat([df,df2])
df3 = df3['URL']
df4 = df3.drop_duplicates()

# %%
print(df4)
# Out:
# 0       https://www.goodreads.com/book/show/2657.To_Ki...
# 1       https://www.goodreads.com/book/show/72193.Harr...
# 2       https://www.goodreads.com/book/show/1885.Pride...
# 3       https://www.goodreads.com/book/show/48855.The_...
# 4       https://www.goodreads.com/book/show/170448.Ani...
#                               ...
# 4894    https://www.goodreads.com/book/show/18158535-r...
# 4895    https://www.goodreads.com/book/show/21569527-t...
# 4897    https://www.goodreads.com/book/show/26085520-e...
# 4898    https://www.goodreads.com/book/show/56732449-t...
# 4899    https://www.goodreads.com/book/show/5598960-se...
# Name: URL, Length: 12775, dtype: object

# %%
df4.to_csv('data/urls.csv',index=False)

# %%
df4
# Out:
# 0       https://www.goodreads.com/book/show/2657.To_Ki...
# 1       https://www.goodreads.com/book/show/72193.Harr...
# 2       https://www.goodreads.com/book/show/1885.Pride...
# 3       https://www.goodreads.com/book/show/48855.The_...
# 4       https://www.goodreads.com/book/show/170448.Ani...
#                               ...
# 4894    https://www.goodreads.com/book/show/18158535-r...
# 4895    https://www.goodreads.com/book/show/21569527-t...
# 4897    https://www.goodreads.com/book/show/26085520-e...
# 4898    https://www.goodreads.com/book/show/56732449-t...
# 4899    https://www.goodreads.com/book/show/5598960-se...
# Name: URL, Length: 12775, dtype: object

# %%
# df = pd.read_csv('data/urls.csv')
df2 = pd.read_csv('data/scraped_data6.csv')
df2
# Out:
#       Unnamed: 0                                                URL
# 0              0  https://www.goodreads.com/book/show/11505797-b...
# 1              1  https://www.goodreads.com/book/show/10818853-f...
# 2              2  https://www.goodreads.com/book/show/62967897-h...
# 3              3  https://www.goodreads.com/book/show/11870085-t...
# 4              4  https://www.goodreads.com/book/show/13335037-d...
# ...          ...                                                ...
# 9895        9895  https://www.goodreads.com/book/show/13074628-p...
# 9896        9896  https://www.goodreads.com/book/show/833923.Eng...
# 9897        9897  https://www.goodreads.com/book/show/22515727-t...
# 9898        9898  https://www.goodreads.com/book/show/26312131-f...
# 9899        9899  https://www.goodreads.com/book/show/248584.Jun...
#
# [9900 rows x 2 columns]

# %%
df3 = pd.concat([df4,df2['URL']])
# df3 = df3['URL']
df4 = df3.drop_duplicates()
df4
# Out:
# 0       https://www.goodreads.com/book/show/2657.To_Ki...
# 1       https://www.goodreads.com/book/show/72193.Harr...
# 2       https://www.goodreads.com/book/show/1885.Pride...
# 3       https://www.goodreads.com/book/show/48855.The_...
# 4       https://www.goodreads.com/book/show/170448.Ani...
#                               ...
# 9895    https://www.goodreads.com/book/show/13074628-p...
# 9896    https://www.goodreads.com/book/show/833923.Eng...
# 9897    https://www.goodreads.com/book/show/22515727-t...
# 9898    https://www.goodreads.com/book/show/26312131-f...
# 9899    https://www.goodreads.com/book/show/248584.Jun...
# Name: URL, Length: 29133, dtype: object

# %%
df4.to_csv('data/book_urls.csv',index=False)

# %%
pd.read_csv('data/book_urls.csv')
# Out:
#                                                      URL
# 0      https://www.goodreads.com/book/show/2657.To_Ki...
# 1      https://www.goodreads.com/book/show/72193.Harr...
# 2      https://www.goodreads.com/book/show/1885.Pride...
# 3      https://www.goodreads.com/book/show/48855.The_...
# 4      https://www.goodreads.com/book/show/170448.Ani...
# ...                                                  ...
# 29128  https://www.goodreads.com/book/show/13074628-p...
# 29129  https://www.goodreads.com/book/show/833923.Eng...
# 29130  https://www.goodreads.com/book/show/22515727-t...
# 29131  https://www.goodreads.com/book/show/26312131-f...
# 29132  https://www.goodreads.com/book/show/248584.Jun...
#
# [29133 rows x 1 columns]

# %%
import csv

# %%
df = pd.read_csv('data/data.csv', on_bad_lines='warn')
df2 = pd.read_csv('data/data2.csv',on_bad_lines='warn')
df3 = pd.read_csv('data/data3.csv',on_bad_lines='warn')
# Out:
# Skipping line 4929: expected 8 fields, saw 25
# Skipping line 5581: expected 8 fields, saw 11

# %%
df.drop_duplicates()
# Out:
#                                               image_url  \
# 0     https://images-na.ssl-images-amazon.com/images...
# 1     https://images-na.ssl-images-amazon.com/images...
# 2     https://images-na.ssl-images-amazon.com/images...
# 3     https://images-na.ssl-images-amazon.com/images...
# 4     https://images-na.ssl-images-amazon.com/images...
# ...                                                 ...
# 5579  https://images-na.ssl-images-amazon.com/images...
# 5580  https://images-na.ssl-images-amazon.com/images...
# 5581  https://images-na.ssl-images-amazon.com/images...
# 5582  https://images-na.ssl-images-amazon.com/images...
# 5583  https://images-na.ssl-images-amazon.com/images...
#
#                                              book_title        book_authors  \
# 0                                 To Kill a Mockingbird          Harper Lee
# 1              Harry Potter and the Philosopher’s Stone        J.K. Rowling
# 2                                   Pride and Prejudice         Jane Austen
# 3                             The Diary of a Young Girl          Anne Frank
# 4                                           Animal Farm       George Orwell
# ...                                                 ...                 ...
# 5579  Kabul Beauty School: An American Woman Goes Be...   Deborah Rodriguez
# 5580                                     How to Be Good         Nick Hornby
# 5581                                          Dreamland        Sarah Dessen
# 5582                                           So B. It         Sarah Weeks
# 5583                                            Circles  Ruby Standing Deer
#
#       book_rating book_rating_count book_review_count  \
# 0            4.26         5,967,122            114803
# 1            4.47         9,774,007            157105
# 2            4.28         4,156,818            109653
# 3            4.19         3,643,442             40341
# 4            3.98         3,776,903             92003
# ...           ...               ...               ...
# 5579         3.66            25,063              2943
# 5580         3.22            56,032              3212
# 5581         3.90            81,362              4653
# 5582         4.11            34,687              3078
# 5583         4.02               325                52
#
#                                               book_desc  \
# 0     The unforgettable novel of a childhood in a sl...
# 1     Harry Potter thinks he is an ordinary boy - un...
# 2     Since its immediate success in 1813, Pride and...
# 3     Discovered in the attic in which she spent the...
# 4     Librarian's note: There is an Alternate Cover ...
# ...                                                 ...
# 5579  Soon after the fall of the Taliban, in 2001, D...
# 5580  Die Ärztin Katie hat alles, was sie sich wünsc...
# 5581  There is an alternate cover edition for this I...
# 5582  Now a major motion picture starring Alfre Wood...
# 5583  With much of the world still undiscovered, a s...
#
#                                                  genres
# 0     ['Classics', 'Fiction', 'Historical Fiction', ...
# 1     ['Fantasy', 'Fiction', 'Young Adult', 'Magic',...
# 2     ['Classics', 'Fiction', 'Romance', 'Historical...
# 3     ['Classics', 'Nonfiction', 'Biography', 'Memoi...
# 4     ['Classics', 'Fiction', 'Dystopia', 'Fantasy',...
# ...                                                 ...
# 5579  ['Nonfiction', 'Memoir', 'Biography', 'Womens'...
# 5580  ['Fiction', 'Contemporary', 'Humor', 'Novels',...
# 5581  ['Young Adult', 'Romance', 'Contemporary', 'Fi...
# 5582  ['Young Adult', 'Realistic Fiction', 'Fiction'...
# 5583  ['Historical Fiction', 'Historical', 'Fiction'...
#
# [5463 rows x 8 columns]

# %%
df2
# Out:
#                                               image_url  \
# 0     https://images-na.ssl-images-amazon.com/images...
# 1     https://images-na.ssl-images-amazon.com/images...
# 2     https://images-na.ssl-images-amazon.com/images...
# 3     https://images-na.ssl-images-amazon.com/images...
# 4     https://images-na.ssl-images-amazon.com/images...
# ...                                                 ...
# 5463  https://images-na.ssl-images-amazon.com/images...
# 5464  https://images-na.ssl-images-amazon.com/images...
# 5465  https://images-na.ssl-images-amazon.com/images...
# 5466  https://images-na.ssl-images-amazon.com/images...
# 5467  https://images-na.ssl-images-amazon.com/images...
#
#                                     book_title     book_authors  book_rating  \
# 0                        To Kill a Mockingbird       Harper Lee         4.26
# 1     Harry Potter and the Philosopher’s Stone     J.K. Rowling         4.47
# 2                          Pride and Prejudice      Jane Austen         4.28
# 3                    The Diary of a Young Girl       Anne Frank         4.19
# 4                                  Animal Farm    George Orwell         3.98
# ...                                        ...              ...          ...
# 5463                         The Witch's Dream  Victoria Danann         4.16
# 5464       Confessions of a Tween Superheroine         J.M. Guy         4.15
# 5465                           The Book of Ivy        Amy Engel         4.14
# 5466                          A Beautiful Dark   Jocelyn Davies         3.89
# 5467                             Divorce Hotel        B.R. Snow         3.95
#
#      book_rating_count book_review_count  \
# 0            5,967,122            114803
# 1            9,774,007            157105
# 2            4,156,818            109653
# 3            3,643,442             40341
# 4            3,776,744             92000
# ...                ...               ...
# 5463             3,804               308
# 5464               166                 6
# 5465            23,961              3120
# 5466            17,864              1327
# 5467               183                17
#
#                                               book_desc  \
# 0     The unforgettable novel of a childhood in a sl...
# 1     Harry Potter thinks he is an ordinary boy - un...
# 2     Since its immediate success in 1813, Pride and...
# 3     Discovered in the attic in which she spent the...
# 4     Librarian's note: There is an Alternate Cover ...
# ...                                                 ...
# 5463  Winner BEST PARANORMAL ROMANCE Series four yea...
# 5464  I’M JAZMIN SKYLYN GILLETTE, AND I HAVE A CONFE...
# 5465  After a brutal nuclear war, the United States ...
# 5466  On the night of Skye’s seventeenth birthday, s...
# 5467  If love is hell, what does that make divorce?T...
#
#                                                  genres
# 0     ['Classics', 'Fiction', 'Historical Fiction', ...
# 1     ['Fantasy', 'Fiction', 'Young Adult', 'Magic',...
# 2     ['Classics', 'Fiction', 'Romance', 'Historical...
# 3     ['Classics', 'Nonfiction', 'Biography', 'Memoi...
# 4     ['Classics', 'Fiction', 'Dystopia', 'Fantasy',...
# ...                                                 ...
# 5463  ['Paranormal', 'Paranormal Romance', 'Romance'...
# 5464  ['Young Adult', 'Fiction', 'Contemporary', 'Ne...
# 5465  ['Dystopia', 'Young Adult', 'Romance', 'Fantas...
# 5466  ['Angels', 'Young Adult', 'Paranormal', 'Fanta...
# 5467                     ['Humor', 'Fiction', 'Horror']
#
# [5468 rows x 8 columns]

# %%
data = pd.concat([df,df2])
data = pd.concat([data,df3])

# %%
d = data.drop_duplicates(subset=['book_title', 'book_authors', 'book_rating'],keep='first')

# %%
d
# Out:
#                                                image_url  \
# 0      https://images-na.ssl-images-amazon.com/images...
# 1      https://images-na.ssl-images-amazon.com/images...
# 2      https://images-na.ssl-images-amazon.com/images...
# 3      https://images-na.ssl-images-amazon.com/images...
# 4      https://images-na.ssl-images-amazon.com/images...
# ...                                                  ...
# 16437  https://images-na.ssl-images-amazon.com/images...
# 16438  https://images-na.ssl-images-amazon.com/images...
# 16439  https://images-na.ssl-images-amazon.com/images...
# 16440  https://images-na.ssl-images-amazon.com/images...
# 16441  https://images-na.ssl-images-amazon.com/images...
#
#                                      book_title    book_authors  book_rating  \
# 0                         To Kill a Mockingbird      Harper Lee         4.26
# 1      Harry Potter and the Philosopher’s Stone    J.K. Rowling         4.47
# 2                           Pride and Prejudice     Jane Austen         4.28
# 3                     The Diary of a Young Girl      Anne Frank         4.19
# 4                                   Animal Farm   George Orwell         3.98
# ...                                         ...             ...          ...
# 16437                          Forever & Always  Jasinda Wilder         3.98
# 16438                            Stroke of Fear        Alla Kar         3.78
# 16439                                Unexpected     Lori Foster         3.86
# 16440                                  Eternity     Sonny Daise         4.25
# 16441                                 Obsessive    Isobel Irons         4.07
#
#       book_rating_count book_review_count  \
# 0             5,967,122            114803
# 1             9,774,007            157105
# 2             4,156,818            109653
# 3             3,643,442             40341
# 4             3,776,903             92003
# ...                 ...               ...
# 16437             9,517               951
# 16438               979                48
# 16439             3,249               142
# 16440                16          1 review
# 16441               122                20
#
#                                                book_desc  \
# 0      The unforgettable novel of a childhood in a sl...
# 1      Harry Potter thinks he is an ordinary boy - un...
# 2      Since its immediate success in 1813, Pride and...
# 3      Discovered in the attic in which she spent the...
# 4      Librarian's note: There is an Alternate Cover ...
# ...                                                  ...
# 16437  Ever,These letters are often all that get me t...
# 16438  From the Amazon Best-Selling Author of the For...
# 16439  Eli Conners expected hired mercenary Ray Verek...
# 16440  Scarlett and Dante have had their share of obs...
# 16441  Hometown Hero. Mr. Perfect. Valedictorian. Mos...
#
#                                                   genres
# 0      ['Classics', 'Fiction', 'Historical Fiction', ...
# 1      ['Fantasy', 'Fiction', 'Young Adult', 'Magic',...
# 2      ['Classics', 'Fiction', 'Romance', 'Historical...
# 3      ['Classics', 'Nonfiction', 'Biography', 'Memoi...
# 4      ['Classics', 'Fiction', 'Dystopia', 'Fantasy',...
# ...                                                  ...
# 16437  ['Romance', 'New Adult', 'Contemporary', 'Cont...
# 16438  ['New Adult', 'Romance', 'Contemporary', 'Youn...
# 16439  ['Romance', 'Contemporary Romance', 'Contempor...
# 16440                                                 []
# 16441  ['Young Adult', 'Disability', 'New Adult', 'Ro...
#
# [26403 rows x 8 columns]

# %%
d[d['book_title'] == 'Throne of Glass']
# Out:
#                                              image_url       book_title  \
# 908  https://images-na.ssl-images-amazon.com/images...  Throne of Glass
#
#       book_authors  book_rating book_rating_count book_review_count  \
# 908  Sarah J. Maas         4.19         1,284,092             86589
#
#                                              book_desc  \
# 908  Meet Celaena Sardothien.Beautiful. Deadly. Des...
#
#                                                 genres
# 908  ['Fantasy', 'Young Adult', 'Romance', 'Fiction...

# %%
d = d.dropna()

# %%
df = d[d['image_url'].str.startswith('https')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26106 entries, 0 to 16441
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   image_url          26106 non-null  object
#  1   book_title         26106 non-null  object
#  2   book_authors       26106 non-null  object
#  3   book_rating        26106 non-null  float64
#  4   book_rating_count  7689 non-null   float64
#  5   book_review_count  25789 non-null  float64
#  6   book_desc          26106 non-null  object
#  7   genres             26106 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 1.8+ MB

# %%
df['book_review_count'] = pd.to_numeric(df['book_review_count'], errors='coerce')
df['book_rating_count'] = df['book_rating_count'].str.replace(',', '').astype(float)
# df['book_rating_count'] = pd.to_numeric(df['book_rating_count'], errors='coerce')

# %%
df.dropna()
# Out:
#                                                image_url  \
# 0      https://images-na.ssl-images-amazon.com/images...
# 1      https://images-na.ssl-images-amazon.com/images...
# 2      https://images-na.ssl-images-amazon.com/images...
# 3      https://images-na.ssl-images-amazon.com/images...
# 4      https://images-na.ssl-images-amazon.com/images...
# ...                                                  ...
# 16436  https://images-na.ssl-images-amazon.com/images...
# 16437  https://images-na.ssl-images-amazon.com/images...
# 16438  https://images-na.ssl-images-amazon.com/images...
# 16439  https://images-na.ssl-images-amazon.com/images...
# 16441  https://images-na.ssl-images-amazon.com/images...
#
#                                      book_title    book_authors  book_rating  \
# 0                         To Kill a Mockingbird      Harper Lee         4.26
# 1      Harry Potter and the Philosopher’s Stone    J.K. Rowling         4.47
# 2                           Pride and Prejudice     Jane Austen         4.28
# 3                     The Diary of a Young Girl      Anne Frank         4.19
# 4                                   Animal Farm   George Orwell         3.98
# ...                                         ...             ...          ...
# 16436                             Fire and Rain     Lauren Dane         3.91
# 16437                          Forever & Always  Jasinda Wilder         3.98
# 16438                            Stroke of Fear        Alla Kar         3.78
# 16439                                Unexpected     Lori Foster         3.86
# 16441                                 Obsessive    Isobel Irons         4.07
#
#        book_rating_count  book_review_count  \
# 0              5967122.0           114803.0
# 1              9774007.0           157105.0
# 2              4156818.0           109653.0
# 3              3643442.0            40341.0
# 4              3776903.0            92003.0
# ...                  ...                ...
# 16436             1959.0               86.0
# 16437             9517.0              951.0
# 16438              979.0               48.0
# 16439             3249.0              142.0
# 16441              122.0               20.0
#
#                                                book_desc  \
# 0      The unforgettable novel of a childhood in a sl...
# 1      Harry Potter thinks he is an ordinary boy - un...
# 2      Since its immediate success in 1813, Pride and...
# 3      Discovered in the attic in which she spent the...
# 4      Librarian's note: There is an Alternate Cover ...
# ...                                                  ...
# 16436  Sequel to "Ascension."Rain is a waitress by da...
# 16437  Ever,These letters are often all that get me t...
# 16438  From the Amazon Best-Selling Author of the For...
# 16439  Eli Conners expected hired mercenary Ray Verek...
# 16441  Hometown Hero. Mr. Perfect. Valedictorian. Mos...
#
#                                                   genres
# 0      ['Classics', 'Fiction', 'Historical Fiction', ...
# 1      ['Fantasy', 'Fiction', 'Young Adult', 'Magic',...
# 2      ['Classics', 'Fiction', 'Romance', 'Historical...
# 3      ['Classics', 'Nonfiction', 'Biography', 'Memoi...
# 4      ['Classics', 'Fiction', 'Dystopia', 'Fantasy',...
# ...                                                  ...
# 16436  ['Paranormal', 'Romance', 'Shapeshifters', 'Pa...
# 16437  ['Romance', 'New Adult', 'Contemporary', 'Cont...
# 16438  ['New Adult', 'Romance', 'Contemporary', 'Youn...
# 16439  ['Romance', 'Contemporary Romance', 'Contempor...
# 16441  ['Young Adult', 'Disability', 'New Adult', 'Ro...
#
# [25789 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26106 entries, 0 to 16441
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   image_url          26106 non-null  object
#  1   book_title         26106 non-null  object
#  2   book_authors       26106 non-null  object
#  3   book_rating        26106 non-null  float64
#  4   book_rating_count  26106 non-null  float64
#  5   book_review_count  25789 non-null  float64
#  6   book_desc          26106 non-null  object
#  7   genres             26106 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 1.8+ MB

# %%
df.to_csv('data/book_data.csv',index=False)
